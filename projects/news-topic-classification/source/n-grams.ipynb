# %%
import os

# %%
assets_dir = os.path.realpath("../assets/annotated_corpus")
train_dir = os.path.join(assets_dir, "train")

# %%
topics = os.listdir(train_dir)

# %%
sentences = []
for t in topics:
    workdir = os.path.join(train_dir, t)
    for filename in os.listdir(workdir):
        with open(os.path.join(workdir, filename)) as f:
            lines = "".join(f.readlines())
            sentences_raw = lines.split("\n\n")
            for s in sentences_raw:
                words = s.split("\n")
                if len(words) == 0 or words[0] == "":
                    continue
                stems = list(map(lambda x: x.split("\t")[1], words))
                if "x" in stems:
                    print(filename)
                sentences.append(stems)
        break
# Out:
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv
# 64830.tsv

# %%
len(sentences)
# Out:
# 1375

# %%
sentences[-1]
# Out:
# ['univers', 'of', 'chicago', 'divin', 'school']
